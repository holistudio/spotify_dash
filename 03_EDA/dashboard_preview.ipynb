# %% [markdown]
# # Tableau Datasets

# %%
import os
import json
import random
import datetime

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
# dataset_dir = os.path.join('..','..','datasets','tracks_playlist_dataset')

df1 = pd.read_csv('words_trackID.csv')
df1.head()
# Out:
#   Unnamed: 0  7k9GuJYLp2AzqokyEdwEw2  1KHdq8NK9QxnGjdXb55NiG  \
# 0       rock                       0                       7
# 1     oldies                       0                       2
# 2    classic                       0                       1
# 3      party                       0                       5
# 4     summer                       0                      12
#
#    2qLMf6TuEC3ruGJg4SMMN6  3S0OXQeoh0w6AY8WQVckRW  5TvE3pk05pyFIGdSY9j4DJ  \
# 0                      23                      78                      32
# 1                      37                     165                      23
# 2                       3                      12                       6
# 3                      76                     246                      40
# 4                     114                     285                      49
#
#    2DHDuADAHoUW6n0z80RLQF  5JDcQAztvZTIkrWoZihgvC  6xJOhSm4SvZwzy3uhWz26O  \
# 0                       4                      18                       1
# 1                       0                      22                       0
# 2                       0                       1                       0
# 3                       4                      15                       0
# 4                      33                      47                       5
#
#    7lLKxcNeJtDTWVRKHovLEC  ...  4fxF8ljwryMZX5c9EKrLFE  \
# 0                       0  ...                       6
# 1                       0  ...                      48
# 2                       0  ...                       9
# 3                       2  ...                     137
# 4                       4  ...                      78
#
#    7ojJ4XvqBhBcteM0zjMebT  3AEZUABDXNtecAOSC1qTfo  5MIrspiQcYqNVB5XARdf5l  \
# 0                      13                       2                       0
# 1                      43                       1                       0
# 2                       9                       0                       0
# 3                      17                      85                       0
# 4                      28                      45                       0
#
#    3DTHLA4DaMpgHrK1fRP2bF  3hPbdPIXZPpyywSxnKNtYh  5VsfM32WcLbMlznpWpprkH  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       1                       0
#
#    5NetSTs4dgiR6GLrZOQcwJ  1Rvl8qsKJurfFTyWLBI9ib  4HnMrFXdsJYVuXRmPCevxH
# 0                       0                      14                       0
# 1                       1                      78                       0
# 2                       0                      17                       0
# 3                      60                      23                       0
# 4                      64                      51                       0
#
# [5 rows x 6018 columns]

# %%
df2 = pd.read_csv('artist_words.csv')
df2.head()
# Out:
#    Unnamed: 0                    artist  rock  oldies  classic  party  summer  \
# 0           0                 Badfinger    99      50       72     17      17
# 1           1                      Hugo    50       4        6     36      38
# 2           2  The Dave Brubeck Quartet     2      23       15     27       6
# 3           3                       311     4       0        0      1       1
# 4           4       Jay & The Americans    44     236       45     21      22
#
#    good  chill  old  ...  issa  justin  ish  rockalt  tropical  depressing  \
# 0    35      9   19  ...     0       0    0        0         0           0
# 1    33     33   11  ...     0       1    2        0         0           0
# 2    20     28    9  ...     0       0    0        0         0           0
# 3     1      3    0  ...     0       0    0        0         0           0
# 4    55     13   60  ...     0       0    0        0         1           0
#
#    lounge  david  wow  jukebox
# 0       0      0    0        0
# 1       1      0    1        1
# 2       8      0    0        0
# 3       0      0    0        0
# 4       1      0    1        4
#
# [5 rows x 659 columns]

# %%
df2[df2['artist'] == 'Kansas']
# Out:
#       Unnamed: 0  artist  rock  oldies  classic  party  summer  good  chill  \
# 1209        1209  Kansas  4703    1897     2908    221     186   414    203
#
#       old  ...  issa  justin  ish  rockalt  tropical  depressing  lounge  \
# 1209  817  ...     0       1    1        5         0           3       3
#
#       david  wow  jukebox
# 1209      4    3        5
#
# [1 rows x 659 columns]

# %%
df3 = pd.read_csv('track_features.csv')
df3.head()
# Out:
#    Unnamed: 0                track_id                               artists  \
# 0           0  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 1           1  1KHdq8NK9QxnGjdXb55NiG                           Landon Pigg
# 2           2  2qLMf6TuEC3ruGJg4SMMN6             Jason Mraz;Colbie Caillat
# 3           3  3S0OXQeoh0w6AY8WQVckRW                            Jason Mraz
# 4           4  5TvE3pk05pyFIGdSY9j4DJ  A Great Big World;Christina Aguilera
#
#                                           album_name  \
# 0                                             Hunger
# 1                                  The Boy Who Never
# 2                We Sing. We Dance. We Steal Things.
# 3                We Sing. We Dance. We Steal Things.
# 4  Is There Anybody Out There? - Track by Track C...
#
#                          track_name  popularity  duration_ms  explicit  \
# 0                            Hunger          56       205594     False
# 1  Falling in Love at a Coffee Shop          58       244986     False
# 2                             Lucky          68       189613     False
# 3                         I'm Yours          75       242946     False
# 4                     Say Something          70       229400     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.442   0.632  ...    -6.770     1       0.0295         0.426
# 1         0.489   0.561  ...    -7.933     1       0.0274         0.200
# 2         0.625   0.414  ...    -8.700     1       0.0369         0.294
# 3         0.703   1.000  ...    -9.331     3       0.0417         0.559
# 4         0.407   1.000  ...    -8.822     1       0.0355         0.857
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.004190    0.0735   0.1960   78.899               4     acoustic
# 1          0.000046    0.1790   0.2380   83.457               3     acoustic
# 2          0.000000    0.1510   0.6690  130.088               4     acoustic
# 3          0.000000    0.0973   0.7120  150.960               4     acoustic
# 4          0.000003    0.0913   0.0765  141.284               3     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Table 1: Top Tracks with ___ Vibes
#
#  1. User selects a couple words describing the mood, style, and/or genre of music they want.
#  2. Dashboard displays top X most popular songs and and top X most popular artist that show up in playlists titled with those words.

# %%
playlist_words = list(df1['Unnamed: 0'])

# %%
track_ids = list(df1.columns[1:])

# %%
def rank_track_ids(words):
    filter_words = []
    for word in words:
        if word in playlist_words:
            filter_words.append(word)
    if len(filter_words) > 0:
        # focus on rows matching the user input word
        filter = df1['Unnamed: 0'].isin(filter_words)
        

        # sum the values in each column
        totals = df1.loc[filter, track_ids].sum()
        totals = list(totals)

        sorted_pairs = sorted(zip(totals, track_ids), reverse=True)
        totals_sorted, track_ids_sorted = zip(*sorted_pairs)
        track_ids_sorted = list(track_ids_sorted)
        totals_sorted = list(totals_sorted)
        return track_ids_sorted, totals_sorted
    else:
        return LookupError('No input words are in list of possible playlist words.')

# %%
def get_track_info(track_ids):
    results = []
    for track_id in track_ids:
        filter = df3['track_id'] == track_id
        track_name = df3[filter]['track_name'].iloc[0]
        artists = df3[filter]['artists'].iloc[0]
        album_name = df3[filter]['album_name'].iloc[0]
        results.append((track_name,artists,album_name))
    return results

# %%
top_x = 20

# given user's selected words
user_words = ['jukebox','tropical']
print(f'Top {top_x} songs with vibes: {", ".join(user_words)}')
print('====================================================')
# rank track_ids based on selected words
track_ids, totals = rank_track_ids(user_words)

# show title, artists, album for top_x songs
top_track_ids = track_ids[:top_x]
top_tracks = get_track_info(top_track_ids)

for i in range(top_x):
    print(i+1, top_tracks[i], totals[i])
# Out:
# Top 20 songs with vibes: jukebox, tropical
# ====================================================
# 1 ('Firestone', 'Kygo;Conrad Sewell', 'Cloud Nine') 93
# 2 ('Stole the Show', 'Kygo;Parson James', 'Cloud Nine') 85
# 3 ('Rivers', 'Thomas Jack', 'Rivers') 57
# 4 ('The Ocean (feat. Shy Martin)', 'Mike Perry;shy martin', 'The Ocean (feat. Shy Martin)') 47
# 5 ('Sun Goes Down (feat. Jasmine Thompson) - Radio Mix', 'Robin Schulz;Jasmine Thompson', 'Prayer') 44
# 6 ('Coming Over (feat. James Hersey)', 'Dillon Francis;Kygo;James Hersey', 'This Mixtape is Fire.') 33
# 7 ("It Ain't Me (with Selena Gomez)", 'Kygo;Selena Gomez', "It Ain't Me (with Selena Gomez)") 32
# 8 ('Oxas', 'GAMPER & DADONI;De Hofnar', 'Oxas') 28
# 9 ('Sugar (feat. Francesco Yates)', 'Robin Schulz;Francesco Yates', 'Sugar') 27
# 10 ('Headlights (feat. Ilsey)', 'Robin Schulz;Ilsey', 'Sugar') 26
# 11 ('Prayer in C - Robin Schulz Radio Edit', 'Lilly Wood and The Prick;Robin Schulz', 'Prayer') 23
# 12 ('First Time', 'Kygo;Ellie Goulding', 'First Time') 19
# 13 ('Capsize', 'FRENSHIP;Emily Warren', 'Truce - EP') 18
# 14 ('My Way', 'Calvin Harris', 'My Way') 16
# 15 ('Closer', 'The Chainsmokers;Halsey', 'Closer') 15
# 16 ('Wake Up Where You Are', 'State of Sound', 'Wake Up Where You Are') 15
# 17 ('This Is What You Came For', 'Calvin Harris;Rihanna', 'This Is What You Came For') 14
# 18 ('Brown Eyed Girl', 'Van Morrison', "Blowin' Your Mind!") 12
# 19 ("Don't Stop Believin'", 'Journey', 'Escape (Bonus Track Version)') 11
# 20 ('Waikiki - Original Mix', 'Deep Chills', 'Waikiki') 11

# %%
# TODO: Ranking issue: Consider normalizing row-wise 'words_trackID.csv'
# otherwise rankings not affected by uncommonly used playlist words.

# %% [markdown]
# ## Plot 2: Artist Vibes
#
#  3. User can also select an artist from the above list and then a word cloud appears showing frequency of words used for playlists containing their songs

# %%
user_artist = 'Ed Sheeran'
filter = df2['artist'] == user_artist
# Select the row (Kansas) and drop artist column
row = df2.loc[filter, df2.columns[2:]].iloc[0]

# Get top 3 words by value
top_pairs = row.sort_values(ascending=False).head(top_x)

# Plot with seaborn
plt.figure(figsize=(6,4))
sns.barplot(x=top_pairs.values, y=top_pairs.index)

plt.title(f"Top {top_x} Words for {user_artist}")
plt.xlabel("ScoreWord")
plt.ylabel("Word")
plt.show()

# %%
from wordcloud import WordCloud

# %%
# Extract frequencies (exclude the 'artist' column)
frequencies = df2.loc[filter, df2.columns[2:]].iloc[0].to_dict()

# Create word cloud
# wc = WordCloud(width=800, height=400, background_color="white", colormap="viridis")
# Define a color function that always returns blue
def blue_color_func(*args, **kwargs):
    return "rgb(31, 119, 180)"  # pure blue, you can adjust RGB

# Create word cloud with uniform color
wc = WordCloud(
    width=800,
    height=400,
    background_color="white",
    color_func=blue_color_func
).generate_from_frequencies(frequencies)

# Plot
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
